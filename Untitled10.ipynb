# %% [markdown]
# <a href="https://colab.research.google.com/github/Irenemariyam/Python-Basics/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
supermarket=files.upload()
# Out:
#      <input type="file" id="files-7c853d0e-9454-4d1a-b2c1-d2e30c5438a8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7c853d0e-9454-4d1a-b2c1-d2e30c5438a8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
teams_and_leagues=files.upload()
# Out:
#      <input type="file" id="files-a53b6281-3c39-4070-bf64-54119f826b36" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a53b6281-3c39-4070-bf64-54119f826b36">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
teamgoals={
    'teams':['spain','england'],
    'goals':[2,4]
}
teamgoaldf= pd.DataFrame(teamgoals)
print(teamgoaldf)
# Out:
#      teams  goals
# 0    spain      2
# 1  england      4

# %%
import pandas as pd

# %%
playercountries={
    'players':['messi','ronaldo'],
    'countries':['argentina','portugal']
}
playercountries= pd.DataFrame(playercountries)
print(playercountries)
# Out:
#    players  countries
# 0    messi  argentina
# 1  ronaldo   portugal

# %%
marks=[20,30,40,50,60,70,80]
marksdf = pd.DataFrame(marks)
print(marksdf)
# Out:
#     0
# 0  20
# 1  30
# 2  40
# 3  50
# 4  60
# 5  70
# 6  80

# %%
import pandas as pd
dataframe=pd.read_csv("Supermarket_sales.csv")
print(dataframe)
# Out:
#        No    InvoiceID Branch       City Customertype  Gender  \
# 0       1  750-67-8428      A     Yangon       Member  Female
# 1       2  226-31-3081      C  Naypyitaw       Normal  Female
# 2       3  631-41-3108      A     Yangon       Normal    Male
# 3       4  123-19-1176      A     Yangon       Member    Male
# 4       5  373-73-7910      A     Yangon       Normal    Male
# ..    ...          ...    ...        ...          ...     ...
# 995   996  233-67-5758      C  Naypyitaw       Normal    Male
# 996   997  303-96-2227      B   Mandalay       Normal  Female
# 997   998  727-02-1313      A     Yangon       Member    Male
# 998   999  347-56-2442      A     Yangon       Normal    Male
# 999  1000  849-09-3807      A     Yangon       Member  Female
#
#                 Productline  Unitprice  Quantity      Tax      Total  \
# 0         Health and beauty      74.69         7  26.1415   548.9715
# 1    Electronic accessories      15.28         5   3.8200    80.2200
# ...

# %%
dataframe.head()
# Out:
#    No    InvoiceID Branch       City Customertype  Gender  \
# 0   1  750-67-8428      A     Yangon       Member  Female
# 1   2  226-31-3081      C  Naypyitaw       Normal  Female
# 2   3  631-41-3108      A     Yangon       Normal    Male
# 3   4  123-19-1176      A     Yangon       Member    Male
# 4   5  373-73-7910      A     Yangon       Normal    Male
#
#               Productline  Unitprice  Quantity      Tax     Total       Date  \
# 0       Health and beauty      74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories      15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle      46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty      58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel      86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross_margin_percentage  gross_iincome  Rating
# ...

# %%
dataframe.tail()
# Out:
#        No    InvoiceID Branch       City Customertype  Gender  \
# 995   996  233-67-5758      C  Naypyitaw       Normal    Male
# 996   997  303-96-2227      B   Mandalay       Normal  Female
# 997   998  727-02-1313      A     Yangon       Member    Male
# 998   999  347-56-2442      A     Yangon       Normal    Male
# 999  1000  849-09-3807      A     Yangon       Member  Female
#
#              Productline  Unitprice  Quantity      Tax      Total       Date  \
# 995    Health and beauty      40.35         1   2.0175    42.3675  1/29/2019
# 996   Home and lifestyle      97.38        10  48.6900  1022.4900   3/2/2019
# 997   Food and beverages      31.84         1   1.5920    33.4320   2/9/2019
# 998   Home and lifestyle      65.82         1   3.2910    69.1110  2/22/2019
# 999  Fashion accessories      88.34         7  30.9190   649.2990  2/18/2019
#
#       Time  Payment    cogs  gross_margin_percentage  gross_iincome  Rating
# ...

# %%
dataframe['City'].head()
# Out:
# 0       Yangon
# 1    Naypyitaw
# 2       Yangon
# 3       Yangon
# 4       Yangon
# Name: City, dtype: object

# %%
dataframe['Branch'].head()
# Out:
# 0    A
# 1    C
# 2    A
# 3    A
# 4    A
# Name: Branch, dtype: object

# %%
dataframe[['Branch','City']].head()
# Out:
#   Branch       City
# 0      A     Yangon
# 1      C  Naypyitaw
# 2      A     Yangon
# 3      A     Yangon
# 4      A     Yangon

# %%
print(dataframe.index)
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
for i in dataframe.index:
  print(dataframe.City[i],dataframe.Branch[i])
# Out:
# Yangon A
# Naypyitaw C
# Yangon A
# Yangon A
# Yangon A
# Naypyitaw C
# Yangon A
# Naypyitaw C
# Yangon A
# Mandalay B
# Mandalay B
# Mandalay B
# Yangon A
# Yangon A
# Yangon A
# Mandalay B
# Yangon A
# Yangon A
# Yangon A
# Mandalay B
# Naypyitaw C
# Mandalay B
# Mandalay B
# Yangon A
# Yangon A
# Yangon A
# Mandalay B
# Yangon A
# Mandalay B
# Yangon A
# Mandalay B
# Mandalay B
# Mandalay B
# Yangon A
# Naypyitaw C
# Naypyitaw C
# Yangon A
# Yangon A
# Naypyitaw C
# Mandalay B
# Mandalay B
# Naypyitaw C
# Mandalay B
# Naypyitaw C
# Naypyitaw C
# Mandalay B
# Mandalay B
# Mandalay B
# Mandalay B
# Naypyitaw C
# Naypyitaw C
# Yangon A
# Mandalay B
# Naypyitaw C
# Mandalay B
# Naypyitaw C
# Yangon A
# Yangon A
# Yangon A
# Naypyitaw C
# Naypyitaw C
# Naypyitaw C
# Mandalay B
# Yangon A
# Mandalay B
# Yangon A
# Naypyitaw C
# Mandalay B
# Yangon A
# Yangon A
# Naypyitaw C
# Naypyitaw C
# Mandalay B
# Naypyitaw C
# Yangon A
# Naypyitaw C
# Naypyitaw C
# Yangon A
# Naypyitaw C
# ...

# %%
from google.colab import files
players=files.upload()
# Out:
#      <input type="file" id="files-b24df874-320c-4a45-88ea-7fcf86ee3415" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b24df874-320c-4a45-88ea-7fcf86ee3415">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
fifadataframe = pandas.read_csv("players_20.csv")
max_overall=fifadataframe.overall.max()
max_overall_loc = fifadataframe.overall.idxmax()
person=fifadataframe.loc[max_overall_loc]
print(person.long_name,"has the height overall of",max_overall)
# Out:
# Lionel Andrés Messi Cuccittini has the height overall of 94

# %%
fifadataframe = pandas.read_csv("players_20.csv")
min_age=fifadataframe.age.min()
print(min_age)
# Out:
# 16

# %%
fifadataframe = pandas.read_csv("players_20.csv")
min_age=fifadataframe.age.min()
min_age_loc = fifadataframe.age.idxmin()
person=fifadataframe.loc[min_age_loc]
print(person.long_name,"has the age of",min_age)
# Out:
# Adam Hložek has the age of 16

# %%
average_age = fifadataframe.age.mean()
print(average_age)
# Out:
# 25.283291388554545

# %%
for i in fifadataframe.index:
  if fifadataframe.club[i]== "FC Barcelona":
    print(fifadataframe.short_name[i])
# Out:
# L. Messi
# M. ter Stegen
# L. Suárez
# Sergio Busquets
# A. Griezmann
# Piqué
# Jordi Alba
# S. Umtiti
# I. Rakitić
# F. de Jong
# C. Lenglet
# Neto
# O. Dembélé
# Arthur
# A. Vidal
# Nélson Semedo
# Sergi Roberto
# Rafinha
# Junior Firpo
# Aleñá
# Riqui Puig
# J. Todibo
# M. Wagué
# H. Abe
# L. Reis
# Abel Ruiz
# Oriol Busquets
# Carles Pérez
# Miranda
# Chumi
# Álex Collado
# Jorge Cuenca
# Iñaki Peña
